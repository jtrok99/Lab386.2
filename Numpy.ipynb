# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#
# File c:\Users\Owner\Documents\1. Per Scholas\Lab386.2\NumbyLab\Lib\site-packages\numpy\__init__.py:125
#     122 from . import _distributor_init
#     124 try:
# --> 125     from numpy.__config__ import show_config
#     126 except ImportError as e:
#     127     if isinstance(e, ModuleNotFoundError) and e.name == "numpy.__config__":
#     128         # The __config__ module itself was not found, so add this info:
#
# File c:\Users\Owner\Documents\1. Per Scholas\Lab386.2\NumbyLab\Lib\site-packages\numpy\__config__.py:4
#       1 # This file is generated by numpy's build process
#       2 # It contains system_info results at the time of building this package.
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
# ...

# %%
# Define a list of dishes on the menu
menu = [
    "Spaghetti Carbonara",
    "Chicken Alfredo",
    "Margherita Pizza",
    "Cheeseburger",
    "Caesar Salad",
    "Fish and Chips",
    "Pad Thai",
    "Sushi Platter",
    "Vegetable Stir-Fry",
    "Grilled Salmon"
]

# %%
def suggest_dish():
    random.dish = random.choice(menu)
    return random.dish

# %%
print(suggest_dish())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(suggest_dish())
#
# Cell In[2], line 2, in suggest_dish()
#       1 def suggest_dish():
# ----> 2     random.dish = random.choice(menu)
#       3     return random.dish
#
# NameError: name 'random' is not defined

# %%
from numpy import random

data = random.randn(10)
print(data)
# Out:
# [-0.33418562  0.22252184  0.22743379 -0.36553881 -0.60239607  0.19123614
#   1.53828486 -2.35387573 -0.3863258  -1.43944822]

# %%
random_numbers = random.randn(5)
print(random_numbers * 1000)
# Out:
# [ -131.17357617   251.26045882  -597.19893277  2420.83738392
#  -1051.3516067 ]

# %%
elements = ['a', 'b', 'c', 'd', 'e']
random_sample = random.choice(elements)
print (random_sample)
# Out:
# b

# %%
random.shuffle(elements)
print(elements)
# Out:
# ['e', 'a', 'c', 'd', 'b']

# %%
menu = [
    "Spaghetti Carbonara",
    "Chicken Alfredo",
    "Beef Lasagna"
]

def suggest_dish():
    random_dish = random.choice(menu)
    return random_dish

# %%
print(suggest_dish())
# Out:
# Spaghetti Carbonara
