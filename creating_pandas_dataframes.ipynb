# %%
import numpy as np
import pandas as pd 

d = {'x' : [1, 2, 3], 'y' : [2,4,8], 'z' :100}
df = pd.DataFrame(d)
df.head()
# Out:
#    x  y    z
# 0  1  2  100
# 1  2  4  100
# 2  3  8  100

# %%
df2 = pd.DataFrame(d, index=[100, 200, 300], columns=['z', 'y', 'x'])

df2.head()
# Out:
#        z  y  x
# 100  100  2  1
# 200  100  4  2
# 300  100  8  3

# %%
student_dict = {'name': ['Joe', 'Nat', 'Henry'], 'age': [20, 21, 19], 'grade': ['A', 'B', 'C']}
student_df = pd.DataFrame(student_dict)
student_df.head()
# Out:
#     name  age grade
# 0    Joe   20     A
# 1    Nat   21     B
# 2  Henry   19     C

# %%
student_df = student_df.set_index('name')
student_df.head()
print(student_df.head())
# Out:
#        age grade
# name
# Joe     20     A
# Nat     21     B
# Henry   19     C

# %%
data = {'Product' : ['Laptop', 'Tablet', 'Smartphone'], 'Price' : [1200, 300, 800], 'Quantity' : [10, 20, 15]}
df3 = pd.DataFrame(data)
df3.head()
# Out:
#       Product  Price  Quantity
# 0      Laptop   1200        10
# 1      Tablet    300        20
# 2  Smartphone    800        15

# %%
df3.index = pd.RangeIndex(start=1, stop=4, step=1)
df3.head()
# Out:
#       Product  Price  Quantity
# 1      Laptop   1200        10
# 2      Tablet    300        20
# 3  Smartphone    800        15

# %%
patient_ID = [101, 102, 103]
name = ['Alice', 'Bob', 'Charlie']
date_of_birth = ['1990-01-01', '1985-06-15', '1992-03-22']

employee_df = pd.DataFrame(zip(patient_ID, name, date_of_birth), columns=['Patient ID', 'Name', 'Date of Birth'])
employee_df
# Out:
#    Patient ID     Name Date of Birth
# 0         101    Alice    1990-01-01
# 1         102      Bob    1985-06-15
# 2         103  Charlie    1992-03-22
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
data = {
    'Product': ['Laptop', 'Tablet', 'Phone'],
    'Price': [1200, 300, 800],
    'Quantity': [50, 150, 100]
}
df3 = pd.DataFrame(data)

df3.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       2     'Product': ['Laptop', 'Tablet', 'Phone'],
#       3     'Price': [1200, 300, 800],
#       4     'Quantity': [50, 150, 100]
#       5 }
# ----> 6 df3 = pd.DataFrame(data)
#       7
#       8 df3.head()
#
# NameError: name 'pd' is not defined
